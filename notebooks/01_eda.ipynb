# %%
# !pip install pandas numpy matplotlib seaborn scikit-learn joblib
# Out:
# ...
#    ---------------------------------------- 0.0/9.7 MB ? eta -:--:--
#    --- ------------------------------------ 0.8/9.7 MB 3.3 MB/s eta 0:00:03
#    ------- -------------------------------- 1.8/9.7 MB 4.5 MB/s eta 0:00:02
#    --------- ------------------------------ 2.4/9.7 MB 4.3 MB/s eta 0:00:02
#    --------------- ------------------------ 3.7/9.7 MB 4.3 MB/s eta 0:00:02
#    ------------------ --------------------- 4.5/9.7 MB 4.4 MB/s eta 0:00:02
#    ---------------------- ----------------- 5.5/9.7 MB 4.4 MB/s eta 0:00:01
#    ------------------------- -------------- 6.3/9.7 MB 4.5 MB/s eta 0:00:01
#    ------------------------------ --------- 7.3/9.7 MB 4.4 MB/s eta 0:00:01
#    --------------------------------- ------ 8.1/9.7 MB 4.3 MB/s eta 0:00:01
#    ------------------------------------- -- 9.2/9.7 MB 4.4 MB/s eta 0:00:01
#    ---------------------------------------  9.7/9.7 MB 4.3 MB/s eta 0:00:01
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Display settings
pd.set_option('display.max_columns', None)
plt.style.use('default')
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
# Load loan dataset
loan_df = pd.read_csv("../data/loan_data.csv")

# Load transaction dataset
txn_df = pd.read_csv("../data/transactions.csv")

print("Loan Dataset Shape:", loan_df.shape)
print("Transaction Dataset Shape:", txn_df.shape)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 2
#       1 # Load loan dataset
# ----> 2 loan_df = pd.read_csv("../data/loan_data.csv")
#       4 # Load transaction dataset
#       5 txn_df = pd.read_csv("../data/transactions.csv")
#
# ...

# %%
import os
os.getcwd()
# Out:
# 'c:\\Users\\Dell\\Desktop\\AI_Banking_System\\notebooks'

# %%
import os
os.listdir("../data")
# Out:
# ['Bank_Transaction_Fraud_Detection.csv', 'loan_sanction_test.csv']

# %%
# Load loan dataset
loan_df = pd.read_csv("../data/loan_sanction_test.csv")

# Load transaction dataset
txn_df = pd.read_csv("../data/Bank_Transaction_Fraud_Detection.csv")

print("Loan Data Shape:", loan_df.shape)
print("Transaction Data Shape:", txn_df.shape)
# Out:
# Loan Data Shape: (367, 12)
# Transaction Data Shape: (200000, 24)
